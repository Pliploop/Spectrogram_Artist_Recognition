# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('whitegrid')
import datetime
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data/data/unsplit_dataset.csv')
dataset.year=dataset.year.apply(lambda x:x[0:4])

# %%
dataset
# Out:
#              artist                  song            album  year    genre  \
# 0     Ariana Grande                 Intro    My Everything  2014      Pop
# 1     Ariana Grande      Honeymoon Avenue      Yours Truly  2013      R&B
# 2     Ariana Grande             Moonlight  Dangerous Woman  2016      R&B
# 3     Ariana Grande               Imagine    Thank U, Next  2019  Hip Hop
# 4     Ariana Grande  No Tears Left To Cry   Greatest Songs  2018      Pop
# ...             ...                   ...              ...   ...      ...
# 3062     The Weeknd     Until I Bleed Out      After Hours  2020      R&B
# 3063     The Weeknd   Nothing Without You          Starboy  2016      R&B
# 3064     The Weeknd            All I Know          Starboy  2016      R&B
# 3065     The Weeknd           Die For You          Starboy  2016      R&B
# 3066     The Weeknd      I Feel It Coming          Starboy  2016      R&B
#
#                                       uuid    duration  rms  \
# 0     cd613e30-d8f1-4adf-91b7-584a2265b1f5   79.933343    0
# 1     d95bafc8-f2a4-427b-9cf4-bb99f4bea973  340.075277    0
# 2     21636369-8b52-4b4a-97b7-50923ceb3ffd  202.578366    0
# 3     b8a1abcd-1a69-46c7-8da4-f9fc3c6da5d7  212.310892    0
# 4     5bc8fbbc-bde5-4099-8164-d8399f767c45  223.390501    0
# ...                                    ...         ...  ...
# 3062  3c79cfa1-d1d1-4de8-af70-041e7d3cdccc  190.413412    0
# 3063  09904bfe-6bef-4ada-8fb1-ba8ec8ad79eb  198.884341    0
# 3064  5332170b-9202-46e3-b5c5-ca0372d0e078  321.373280    0
# 3065  0c2b4443-ffff-4ab2-9f2f-eef86d6b58af  260.534071    0
# 3066  b0b68d6b-7e36-43da-ba76-75101c960665  269.475631    0
#
#                               path
# 0                   01 - Intro.mp3
# 1          01 Honeymoon Avenue.mp3
# 2                 01 Moonlight.mp3
# 3                  01. imagine.mp3
# 4     01. No Tears Left To Cry.mp3
# ...                            ...
# 3062      14 Until I Bleed Out.mp3
# 3063    15 Nothing Without You.mp3
# 3064             16 All I Know.mp3
# 3065            17 Die For You.mp3
# 3066       18 I Feel It Coming.mp3
#
# [3067 rows x 9 columns]

# %%
dataset.genre.unique()
# Out:
# array(['Pop', 'R&B', 'Hip Hop', 'Unknown', 'Alternative', 'Rock',
#        'Classic Rock', 'Soul', 'Pop/Rock'], dtype=object)

# %%
def simple_genre(x):
    if x in ['Europop/Synth-Pop/Rhythm & Blues','Pop','Pop, R&B','ポップ','Asian Music']:
        return 'Pop'
    if x in ['Rnb/Swing','Contemporary R&B',"R&B/Pop","R&B, Reggae","R&B/Soul"]:
        return 'R&B'
    if x in ['Trap/Rnb/Swing','Rap/Hip Hop','Hip Hop/Rap','Hip-Hop/Rap','Rap',"Rap & Hip-Hop","Hip-Hop","Rap/Hip Hop;Pop"]:
        return "Hip Hop"
    if x in ['Afrikaanse Muziek','Dance']:
        return 'Unknown'
    else:
        return x

# %%
dataset.genre=dataset.genre.apply(simple_genre)

# %%
sns.barplot(data=dataset.groupby('artist').count().reset_index(),y="artist",x='uuid')
# Out:
# <AxesSubplot:xlabel='uuid', ylabel='artist'>

# %%
sns.barplot(data=dataset.groupby('genre').count().reset_index(),y="genre",x='uuid', palette='Blues_r')
# Out:
# <AxesSubplot:xlabel='uuid', ylabel='genre'>

# %%
sns.histplot(dataset.duration/60,kde=True,bins=50)
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %%
fig,axes=plt.subplots(1,1,figsize=(15,15))
sns.barplot(data=dataset.groupby('year').count().reset_index().sort_values('year'),y="year",x='uuid',ax=axes)
# Out:
# <AxesSubplot:xlabel='uuid', ylabel='year'>

# %%
sns.kdeplot(dataset.year[dataset.year != 'None'].apply(lambda x:x[0:4]).astype(int))
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
file_dir = '../data/data.unsplit_data'

# %%
unsplit_path = '../data/data.unsplit_data/Ariana Grande/'+dataset[dataset.song=='positions'].iloc[0].path
split_path = '../data/data/split_pool/'+dataset[dataset.song=='positions'].iloc[0].uuid+'.mp3'

# %%
import librosa
import matplotlib.pyplot as plt
y, sr = librosa.load(librosa.ex('unsplit_path'))
fig, ax = plt.subplots((1,1),figsize = (15,10))
librosa.display.waveplot(y, sr=sr, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-8c67d1a1765b> in <module>
# ----> 1 import librosa
#       2 import matplotlib.pyplot as plt
#       3 y, sr = librosa.load(librosa.ex('unsplit_path'))
#       4 fig, ax = plt.subplots((1,1),figsize = (15,10))
#       5 librosa.display.waveplot(y, sr=sr, ax=ax)
#
# ModuleNotFoundError: No module named 'librosa'
